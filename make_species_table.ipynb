# %%
import pandas as pd
import pickle

# %%
data = pd.read_json('data/All_species.json')

# %%
counts = data['querySpecificObservationCount']

# %%
agg = []
for i, taxa in enumerate(data['taxon']):
    agg.append([counts[i], taxa.get('commonName'), taxa['name'], taxa['organismKey'], taxa['rank'], taxa['gatewayRecordCount']])

# %%
df= pd.DataFrame(agg)

# %%
df.columns= ['observation_count', 'common_name', 'scientific_name', 'species_key', 'rank', 'record_count']

# %%
df['common_name'][pd.isnull(df['common_name'])]=''
df['common_name'] = df['common_name'].apply(lambda x: x.encode('ascii', 'ignore'))
# Out:
# /Applications/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
df.to_csv('data/species_table.csv')

# %%
df
# Out:
#       observation_count                      common_name  \
# 0                     1
# 1                     1
# 2                   283                       Velvetleaf
# 3                    16
# 4                     3                   Hickory Wattle
# 5                    10             Australian Blackwood
# 6                    84
# 7                    73           Bronze Pirri-pirri-bur
# 8                     8
# 9                     7         Glaucous Pirri-pirri-bur
# 10                   69                 Spineless Acaena
# 11                    6
# 12                    1
# 13                  413                  Pirri-pirri-bur
# 14                  146                Two-spined Acaena
# 15                    1                        Spiny-bur
# 16                    1
# 17                  594                    Bear's-breech
# 18                   74              Spiny Bear's-breech
# 19                 1254                            Maple
# 20                77944                      Field Maple
# 21                  178                Cappadocian Maple
# 22                    1
# 23                   24                  Snakebark Maple
# 24                   23                  Paperbark Maple
# 25                    1                 Heldrich's Maple
# 26                   24             Downy Japanese-maple
# 27                   13                     Oregon Maple
# 28                    4
# 29                    4                Montpellier Maple
# ...                 ...                              ...
# 7295                  1
# 7296                 24                        Triticale
# 7297                 32              Argentine Cocklebur
# 7298                405                  Spiny Cocklebur
# 7299                207                  Rough Cocklebur
# 7300                  2
# 7301                  1                       Immortelle
# 7302                 15
# 7303                  5                    Adam's-needle
# 7304                 32                   Spanish-dagger
# 7305                 44     Curved-leaved Spanish-dagger
# 7306                 70           Indian Fountain-bamboo
# 7307              10736                  Horned Pondweed
# 7308                  6
# 7309                  2  Stalked-fruited Horned Pondweed
# 7310                118                       Altar-lily
# 7311                  2
# 7312                  2              Californian Fuchsia
# 7313                269                            Maize
# 7314                  2
# 7315                 11                    Caucasian Elm
# 7316                  2                     Japanese Elm
# 7317                  1                          Zenobia
# 7318                  1              Manchurian Wildrice
# 7319                  3
# 7320                515
# 7321                  1
# 7322               5020                         Eelgrass
# 7323               2448                   Dwarf Eelgrass
# 7324                  4
#
#                                 scientific_name       species_key  \
# 0                                        Abelia  NBNORG0000052930
# 1                                      Abutilon  NBNORG0000052939
# 2                          Abutilon theophrasti  NBNORG0000052941
# 3                                        Acacia  NBNORG0000052942
# 4                            Acacia falciformis  NBNORG0000025007
# 5                            Acacia melanoxylon  NBNORG0000052943
# 6                                        Acaena  NBNORG0000052944
# 7                          Acaena anserinifolia  NBNORG0000052945
# 8                Acaena anserinifolia x inermis  NBNORG0000013478
# 9                           Acaena caesiiglauca  NBNORG0000013229
# 10                               Acaena inermis  NBNORG0000052946
# 11                           Acaena magellanica  NBNORG0000052947
# 12                           Acaena microphylla  NBNORG0000052948
# 13                       Acaena novae-zelandiae  NBNORG0000022102
# 14                            Acaena ovalifolia  NBNORG0000052949
# 15                      Acanthospermum australe  NBNORG0000045865
# 16                                     Acanthus  NBNORG0000052955
# 17                              Acanthus mollis  NBNORG0000013396
# 18                            Acanthus spinosus  NBNORG0000013475
# 19                                         Acer  NBNORG0000052956
# 20                               Acer campestre  NBNORG0000007757
# 21                            Acer cappadocicum  NBNORG0000013325
# 22                             Acer cissifolium  NBNORG0000047641
# 23                                 Acer davidii  NBNORG0000025008
# 24                                 Acer griseum  NBNORG0000025009
# 25                             Acer heldreichii  NBNORG0000025010
# 26                               Acer japonicum  NBNORG0000025011
# 27                            Acer macrophyllum  NBNORG0000025012
# 28                                    Acer mono  NBNORG0000008772
# 29                          Acer monspessulanum  NBNORG0000025013
# ...                                         ...               ...
# 7295                          X Tripleurothemis  NBNORG0000057129
# 7296                            X Triticosecale  NBNORG0000057130
# 7297                      Xanthium ambrosioides  NBNORG0000023584
# 7298                          Xanthium spinosum  NBNORG0000008502
# 7299                        Xanthium strumarium  NBNORG0000008501
# 7300                                Xeranthemum  NBNORG0000057132
# 7301                         Xeranthemum annuum  NBNORG0000047334
# 7302                                      Yucca  NBNORG0000057135
# 7303                          Yucca filamentosa  NBNORG0000047335
# 7304                             Yucca gloriosa  NBNORG0000047336
# 7305                         Yucca recurvifolia  NBNORG0000023550
# 7306                            Yushania anceps  NBNORG0000057137
# 7307                     Zannichellia palustris  NBNORG0000007148
# 7308    Zannichellia palustris subsp. palustris  NBNORG0000057139
# 7309  Zannichellia palustris subsp. pedicellata  NBNORG0000057140
# 7310                    Zantedeschia aethiopica  NBNORG0000057142
# 7311                                Zauschneria  NBNORG0000057143
# 7312                    Zauschneria californica  NBNORG0000047338
# 7313                                   Zea mays  NBNORG0000013268
# 7314                                    Zelkova  NBNORG0000057145
# 7315                       Zelkova carpinifolia  NBNORG0000057146
# 7316                            Zelkova serrata  NBNORG0000025108
# 7317                       Zenobia pulverulenta  NBNORG0000057148
# 7318                          Zizania latifolia  NBNORG0000057153
# 7319                          Ziziphora taurica  NBNORG0000047343
# 7320                                    Zostera  NBNORG0000113040
# 7321                          Zostera (Zostera)  NBNORG0000113043
# 7322                   Zostera (Zostera) marina  NBNORG0000007128
# 7323                Zostera (Zosterella) noltei  NBNORG0000043632
# 7324                    x Festulolium nilssonii  NBNORG0000043600
#
#                 rank  record_count
# 0              Genus             2
# 1              Genus           304
# 2            Species           300
# 3              Genus            87
# 4            Species             3
# 5            Species            11
# 6              Genus           824
# 7            Species            74
# 8     Species hybrid             8
# 9            Species             7
# 10           Species            69
# 11           Species             6
# 12           Species             1
# 13           Species           425
# 14           Species           148
# 15           Species             1
# 16             Genus           756
# 17           Species           658
# 18           Species            87
# 19             Genus        268586
# 20           Species         90802
# 21           Species           321
# 22           Species             1
# 23           Species            44
# 24           Species            40
# 25           Species             1
# 26           Species            28
# 27           Species            19
# 28           Species            13
# 29           Species             9
# ...              ...           ...
# 7295  Generic hybrid            12
# 7296  Generic hybrid            25
# 7297         Species            32
# 7298         Species           406
# 7299         Species           212
# 7300           Genus             3
# 7301         Species             1
# 7302           Genus           141
# 7303         Species             6
# 7304         Species            52
# 7305         Species            47
# 7306         Species            72
# 7307         Species         11162
# 7308      Subspecies             9
# 7309      Subspecies             8
# 7310         Species           124
# 7311           Genus             4
# 7312         Species             2
# 7313         Species           314
# 7314           Genus           105
# 7315         Species            25
# 7316         Species            73
# 7317         Species             1
# 7318         Species             2
# 7319         Species             3
# 7320           Genus          8471
# 7321        Subgenus             1
# 7322         Species          5296
# 7323         Species          2655
# 7324  Species hybrid             4
#
# [7325 rows x 6 columns]

# %%
# Out:
# 0       {u'languageKey': u'la', u'name': u'Abelia', u'...
# 1       {u'languageKey': u'la', u'name': u'Abutilon', ...
# 2       {u'languageKey': u'la', u'name': u'Abutilon th...
# 3       {u'languageKey': u'la', u'name': u'Acacia', u'...
